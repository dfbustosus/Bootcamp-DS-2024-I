# %%
import pandas as pd
T= pd.read_csv("./Sample_Superstore.csv",sep=",",encoding='unicode_escape')
T
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
import seaborn as sns
sns.histplot(T.Sales)
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %%
# %ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 8444-34B1
#
#  Directory of c:\Users\david\Desktop\BIT\Bootcamp-DS-2024-I\Clase 12
#
# 15-08-2024  20:56    <DIR>          .
# 15-08-2024  18:40    <DIR>          ..
# 15-08-2024  20:24           702.148 1) Visualizaciones_ Plotly.ipynb
# 15-08-2024  20:44           608.840 2) Visualizaciones_ Folium basico.ipynb
# 18-04-2024  19:52                 0 4.2.0
# 15-08-2024  20:34             4.253 base_map.html
# 31-10-2023  18:03            91.617 Boxplot.jpeg
# 15-08-2024  19:56         3.633.811 Boxplot_prueba.html
# 31-10-2023  18:03        10.198.609 Clase 12 - GIS y Datos Espaciales.pptx
# 31-10-2023  18:03            46.163 figura_ejemplo.jpeg
# 15-08-2024  20:55         2.287.806 Sample_Superstore.csv
# 15-08-2024  20:55                 0 Test.ipynb
#               10 File(s)     17.573.247 bytes
#                2 Dir(s)  117.824.974.848 bytes free
