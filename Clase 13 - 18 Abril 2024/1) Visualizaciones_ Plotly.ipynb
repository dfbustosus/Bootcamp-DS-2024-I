# %% [markdown]
# # PLotly

# %%
# !pip install chart_studio
# !pip install plotly

# %%
# Importar librerias
import pandas as pd
import numpy as np
#import chart_studio.plotly as py
import seaborn as sns
import plotly.express as px
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode,plot,plot, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.20.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Elementos basicos

# %%
arr= np.random.randn(50,4)
df= pd.DataFrame(arr, columns=['A','B','C','D'])
df.head()
df.plot()
# Out:
# <Axes: >

# %%
df_stocks = px.data.stocks()
df_stocks
# Out:
#            date      GOOG      AAPL      AMZN        FB      NFLX      MSFT
# 0    2018-01-01  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1    2018-01-08  1.018172  1.011943  1.061881  0.959968  1.053526  1.015988
# 2    2018-01-15  1.032008  1.019771  1.053240  0.970243  1.049860  1.020524
# 3    2018-01-22  1.066783  0.980057  1.140676  1.016858  1.307681  1.066561
# 4    2018-01-29  1.008773  0.917143  1.163374  1.018357  1.273537  1.040708
# ..          ...       ...       ...       ...       ...       ...       ...
# 100  2019-12-02  1.216280  1.546914  1.425061  1.075997  1.463641  1.720717
# 101  2019-12-09  1.222821  1.572286  1.432660  1.038855  1.421496  1.752239
# 102  2019-12-16  1.224418  1.596800  1.453455  1.104094  1.604362  1.784896
# 103  2019-12-23  1.226504  1.656000  1.521226  1.113728  1.567170  1.802472
# 104  2019-12-30  1.213014  1.678000  1.503360  1.098475  1.540883  1.788185
#
# [105 rows x 7 columns]

# %%
# Informacion de datos disponibles: https://plotly.com/python-api-reference/generated/plotly.data.html
# Precio de stocks de ['date', 'GOOG', 'AAPL', 'AMZN', 'FB', 'NFLX', 'MSFT']
# para 2018/2019
px.line(df_stocks, x='date',y='GOOG', labels={'x':'Fecha', 'y':'Precio'})
# Out:
# <div>                            <div id="b4a9e129-0a7d-4ef3-ae52-df7abeda2e64" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b4a9e129-0a7d-4ef3-ae52-df7abeda2e64")) {                    Plotly.newPlot(                        "b4a9e129-0a7d-4ef3-ae52-df7abeda2e64",                        [{"hovertemplate":"date=%{x}<br>GOOG=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2018-01-01","2018-01-08","2018-01-15","2018-01-22","2018-01-29","2018-02-05","2018-02-12","2018-02-19","2018-02-26","2018-03-05","2018-03-12","2018-03-19","2018-03-26","2018-04-02","2018-04-09","2018-04-16","2018-04-23","2018-04-30","2018-05-07","2018-05
# ...

# %%
px.line?

# %%
px.line(df_stocks, x='date', y=['GOOG','AAPL'],labels={'x':'Date','y':'Price'},
        title='Apple vs Google')
# Out:
# <div>                            <div id="0ea11c96-b6c9-4239-8bba-e4d410bfc94b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ea11c96-b6c9-4239-8bba-e4d410bfc94b")) {                    Plotly.newPlot(                        "0ea11c96-b6c9-4239-8bba-e4d410bfc94b",                        [{"hovertemplate":"variable=GOOG<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"GOOG","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"GOOG","orientation":"v","showlegend":true,"x":["2018-01-01","2018-01-08","2018-01-15","2018-01-22","2018-01-29","2018-02-05","2018-02-12","2018-02-19","2018-02-26","2018-03-05","2018-03-12","2018-03-19","2018-03-26","2018-04-02","2018-04-09","2018-04-16","2018-04-23","2018-04-
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=df_stocks.date, y=df_stocks.AAPL,mode='lines', name='Apple'))
fig.add_trace(go.Scatter(x=df_stocks.date, y=df_stocks.AMZN,mode='lines+markers', name='Amazon'))
fig.add_trace(go.Scatter(x=df_stocks.date, y=df_stocks.GOOG,
                         mode='lines+markers', name='Google',
                         line=dict(color='firebrick',width=2,
                                   dash='dashdot')))
fig.update_layout(title='Precio de acciones 2018/19',
                  xaxis_title='Precio',yaxis_title='Fecha')
# Out:
# <div>                            <div id="c6bb1dba-5c5e-4d4b-9007-3a15e3a94525" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c6bb1dba-5c5e-4d4b-9007-3a15e3a94525")) {                    Plotly.newPlot(                        "c6bb1dba-5c5e-4d4b-9007-3a15e3a94525",                        [{"mode":"lines","name":"Apple","x":["2018-01-01","2018-01-08","2018-01-15","2018-01-22","2018-01-29","2018-02-05","2018-02-12","2018-02-19","2018-02-26","2018-03-05","2018-03-12","2018-03-19","2018-03-26","2018-04-02","2018-04-09","2018-04-16","2018-04-23","2018-04-30","2018-05-07","2018-05-14","2018-05-21","2018-05-28","2018-06-04","2018-06-11","2018-06-18","2018-06-25","2018-07-02","2018-07-09","2018-07-16","2018-07-23","2018-07-30","2018-08-06","2018-08-13","2
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=df_stocks.date, y=df_stocks.AAPL,
                         mode='lines', name='Apple'))
fig.add_trace(go.Scatter(x=df_stocks.date, y=df_stocks.AMZN,
                         mode='lines+markers', name='Amazon'))
fig.add_trace(go.Scatter(x=df_stocks.date, y=df_stocks.GOOG,
                         mode='lines+markers', name='Google',
                         line=dict(color='firebrick',width=2,
                                   dash='dashdot')))
fig.update_layout(
    xaxis=dict(showline=True, showgrid=False, showticklabels=True,
               linecolor='rgb(204,204,204)', linewidth=2, ticks='outside',
               tickfont=dict(family='Arial', size=12, color='rgb(82,82,82)')
               ),
               yaxis=dict(showgrid=False, zeroline=False, showline=False,
                          showticklabels=False                   
               ),
               autosize=False,
               margin=dict(
                   autoexpand=False,l=100, r=2, t=110),
                           showlegend=True, plot_bgcolor='white'
        )
# Out:
# <div>                            <div id="f5e7c77d-57ef-4bac-b67f-3e526d31884d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f5e7c77d-57ef-4bac-b67f-3e526d31884d")) {                    Plotly.newPlot(                        "f5e7c77d-57ef-4bac-b67f-3e526d31884d",                        [{"mode":"lines","name":"Apple","x":["2018-01-01","2018-01-08","2018-01-15","2018-01-22","2018-01-29","2018-02-05","2018-02-12","2018-02-19","2018-02-26","2018-03-05","2018-03-12","2018-03-19","2018-03-26","2018-04-02","2018-04-09","2018-04-16","2018-04-23","2018-04-30","2018-05-07","2018-05-14","2018-05-21","2018-05-28","2018-06-04","2018-06-11","2018-06-18","2018-06-25","2018-07-02","2018-07-09","2018-07-16","2018-07-23","2018-07-30","2018-08-06","2018-08-13","2
# ...

# %% [markdown]
# # Bar charts

# %%
px.data.gapminder()
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
t=px.data.gapminder().query("country == 'Colombia'")
px.bar(t, x='year',y='gdpPercap')
# Out:
# <div>                            <div id="02bb1a31-b202-4f3a-8510-9b614ff41822" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("02bb1a31-b202-4f3a-8510-9b614ff41822")) {                    Plotly.newPlot(                        "02bb1a31-b202-4f3a-8510-9b614ff41822",                        [{"alignmentgroup":"True","hovertemplate":"year=%{x}<br>gdpPercap=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[1952,1957,1962,1967,1972,1977,1982,1987,1992,1997,2002,2007],"xaxis":"x","y":[2144.115096,2323.805581,2492.351109,2678.729839,3264.660041,3815.80787,4397.575659,4903.2191,5444.648617,6117.361746000001,5755.259962,7006.580
# ...

# %%
px.line(t, x='year',y='gdpPercap')
# Out:
# <div>                            <div id="6fb019f3-ceb1-4040-bd65-8b637f672cf3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6fb019f3-ceb1-4040-bd65-8b637f672cf3")) {                    Plotly.newPlot(                        "6fb019f3-ceb1-4040-bd65-8b637f672cf3",                        [{"hovertemplate":"year=%{x}<br>gdpPercap=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[1952,1957,1962,1967,1972,1977,1982,1987,1992,1997,2002,2007],"xaxis":"x","y":[2144.115096,2323.805581,2492.351109,2678.729839,3264.660041,3815.80787,4397.575659,4903.2191,5444.648617,6117.361746000001,5755.259962,7006.580419],"yaxis":"y","type":"scat
# ...

# %%
df_us= px.data.gapminder().query("country=='United States'")
px.bar(df_us, x='year', y='pop')
# Out:
# <div>                            <div id="26d06f7c-1cbb-4e4b-9318-b07f2f78560c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("26d06f7c-1cbb-4e4b-9318-b07f2f78560c")) {                    Plotly.newPlot(                        "26d06f7c-1cbb-4e4b-9318-b07f2f78560c",                        [{"alignmentgroup":"True","hovertemplate":"year=%{x}<br>pop=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[1952,1957,1962,1967,1972,1977,1982,1987,1992,1997,2002,2007],"xaxis":"x","y":[157553000,171984000,186538000,198712000,209896000,220239000,232187835,242803533,256894189,272911760,287675526,301139947],"yaxis":"y","type":"bar"}], 
# ...

# %%
px.data.tips()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
px.data.tips()[['day','time']].groupby(by=['day']).count().reset_index()
# Out:
#     day  time
# 0   Fri    19
# 1   Sat    87
# 2   Sun    76
# 3  Thur    62

# %%
px.data.tips()[['day','time']].groupby(by=['time']).count().reset_index()
# Out:
#      time  day
# 0  Dinner  176
# 1   Lunch   68

# %%
px.bar(data_frame=px.data.tips()[['day','time']].groupby(by=['day']).count().reset_index(),
       x='day',y='time')
# Out:
# <div>                            <div id="1337babb-4a6b-4d74-ad51-d18beb409fe4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1337babb-4a6b-4d74-ad51-d18beb409fe4")) {                    Plotly.newPlot(                        "1337babb-4a6b-4d74-ad51-d18beb409fe4",                        [{"alignmentgroup":"True","hovertemplate":"day=%{x}<br>time=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Fri","Sat","Sun","Thur"],"xaxis":"x","y":[19,87,76,62],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colors
# ...

# %%
df_tips= px.data.tips()
px.bar(df_tips, x='day',y='tip',color='sex',
       title='Propinas por genero en cada dia',
       labels={'tip':'Propina', 'day':'Dia de trabajo'})
# Out:
# <div>                            <div id="65655178-6df9-4740-aed2-eefc650f9fe8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("65655178-6df9-4740-aed2-eefc650f9fe8")) {                    Plotly.newPlot(                        "65655178-6df9-4740-aed2-eefc650f9fe8",                        [{"alignmentgroup":"True","hovertemplate":"sex=Female<br>Dia de trabajo=%{x}<br>Propina=%{y}<extra></extra>","legendgroup":"Female","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Female","offsetgroup":"Female","orientation":"v","showlegend":true,"textposition":"auto","x":["Sun","Sun","Sun","Sun","Sun","Sun","Sat","Sat","Sat","Sat","Sat","Sat","Sun","Sun","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Thur","Thur","Fri","Fri","Fri","Fri","Fri","Sat","Sat",
# ...

# %%
px.data.gapminder()
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
df_europe= px.data.gapminder().query("continent == 'Europe' and year == 2007 and pop > 2.e6")

# %%
df_europe= px.data.gapminder().query("continent == 'Europe' and year == 2007 and pop > 2.e6")
fig=px.bar(df_europe, y='pop', x='country', text='pop', color='country')
fig
# Out:
# <div>                            <div id="770727ea-7538-47c6-ba64-92160fde8988" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("770727ea-7538-47c6-ba64-92160fde8988")) {                    Plotly.newPlot(                        "770727ea-7538-47c6-ba64-92160fde8988",                        [{"alignmentgroup":"True","hovertemplate":"country=%{x}<br>pop=%{text}<extra></extra>","legendgroup":"Albania","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Albania","offsetgroup":"Albania","orientation":"v","showlegend":true,"text":[3600523.0],"textposition":"auto","x":["Albania"],"xaxis":"x","y":[3600523],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=%{x}<br>pop=%{text}<extra></extra>","legendgroup":"Austria","marker":
# ...

# %%
fig=px.bar(df_europe.sort_values(by=['gdpPercap'],ascending=False),
            y='gdpPercap', x='country', text='gdpPercap', color='country')
fig
# Out:
# <div>                            <div id="a5827d11-33b8-4d67-849b-26de10aaf2a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a5827d11-33b8-4d67-849b-26de10aaf2a8")) {                    Plotly.newPlot(                        "a5827d11-33b8-4d67-849b-26de10aaf2a8",                        [{"alignmentgroup":"True","hovertemplate":"country=%{x}<br>gdpPercap=%{text}<extra></extra>","legendgroup":"Norway","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Norway","offsetgroup":"Norway","orientation":"v","showlegend":true,"text":[49357.19017],"textposition":"auto","x":["Norway"],"xaxis":"x","y":[49357.19017],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=%{x}<br>gdpPercap=%{text}<extra></extra>","legendgroup":"Irel
# ...

# %%
#df_europe= px.data.gapminder().query("continent == 'Europe' and year == 2007 and pop > 2.e6")
df_europe= px.data.gapminder().query("continent == 'Europe' and year == 2007 and pop > 2.e6").sort_values(by='pop', ascending=True)
fig=px.bar(df_europe, y='pop', x='country', text='pop', color='country')
fig.update_traces(texttemplate= '%{text:.2s}', textposition='outside')
fig.update_layout(uniformtext_minsize=8)
fig.update_layout(xaxis_tickangle= -45)
fig
# Out:
# <div>                            <div id="279d95c1-36f8-4bf3-add1-a8317472f9f5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("279d95c1-36f8-4bf3-add1-a8317472f9f5")) {                    Plotly.newPlot(                        "279d95c1-36f8-4bf3-add1-a8317472f9f5",                        [{"alignmentgroup":"True","hovertemplate":"country=%{x}<br>pop=%{text}<extra></extra>","legendgroup":"Slovenia","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Slovenia","offsetgroup":"Slovenia","orientation":"v","showlegend":true,"text":[2009245.0],"textposition":"outside","x":["Slovenia"],"xaxis":"x","y":[2009245],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"country=%{x}<br>pop=%{text}<extra></extra
# ...

# %% [markdown]
# # Scatterplot

# %%
px.data.gapminder()
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
px.scatter(data_frame=px.data.gapminder(), x='lifeExp',y='pop', color='continent',
           size='gdpPercap')
# Out:
# <div>                            <div id="a81b4117-6f06-4918-babb-0898d92a1915" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a81b4117-6f06-4918-babb-0898d92a1915")) {                    Plotly.newPlot(                        "a81b4117-6f06-4918-babb-0898d92a1915",                        [{"hovertemplate":"continent=Asia<br>lifeExp=%{x}<br>pop=%{y}<br>gdpPercap=%{marker.size}<extra></extra>","legendgroup":"Asia","marker":{"color":"#636efa","size":[779.4453145,820.8530296,853.1007099999998,836.1971382,739.9811057999998,786.11336,978.0114388,852.3959447999998,649.3413952000002,635.341351,726.7340548,974.5803384,9867.084765,11635.79945,12753.27514,14804.6727,18268.65839,19340.10196,19211.14731,18524.02406,19035.57917,20292.01679,23403.55927,29796.048
# ...

# %%
cols_usar=['country','lifeExp','pop','gdpPercap']
px.data.gapminder().query("continent=='Americas'")[cols_usar].\
    groupby(by='country').mean().reset_index()
# Out:
#                 country    lifeExp           pop     gdpPercap
# 0             Argentina  69.060417  2.860224e+07   8955.553783
# 1               Bolivia  52.504583  5.610395e+06   2961.228754
# 2                Brazil  62.239500  1.223121e+08   5829.316653
# 3                Canada  74.902750  2.446297e+07  22410.746340
# 4                 Chile  67.430917  1.120573e+07   6703.289147
# 5              Colombia  63.897750  2.725610e+07   4195.342920
# 6            Costa Rica  70.181417  2.400008e+06   5448.610779
# 7                  Cuba  71.045083  9.232576e+06   6283.258678
# 8    Dominican Republic  61.554500  5.735697e+06   2844.856405
# 9               Ecuador  62.816833  8.212243e+06   5733.624767
# 10          El Salvador  59.633333  4.343441e+06   4431.846597
# 11            Guatemala  56.729417  6.858695e+06   4015.402771
# 12                Haiti  50.165250  5.401634e+06   1620.739290
# 13             Honduras  57.920833  3.920593e+06   2834.413083
# ...

# %%
px.scatter(data_frame=px.data.gapminder().query("continent=='Americas'")[cols_usar].\
           groupby(by='country').mean().reset_index(), 
           x='lifeExp',y='pop', color='country',
           size='gdpPercap')
# Out:
# <div>                            <div id="072bbeee-0b59-4397-8b4f-4c1c0a703c92" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("072bbeee-0b59-4397-8b4f-4c1c0a703c92")) {                    Plotly.newPlot(                        "072bbeee-0b59-4397-8b4f-4c1c0a703c92",                        [{"hovertemplate":"country=Argentina<br>lifeExp=%{x}<br>pop=%{y}<br>gdpPercap=%{marker.size}<extra></extra>","legendgroup":"Argentina","marker":{"color":"#636efa","size":[8955.553782666668],"sizemode":"area","sizeref":65.65287836666667,"symbol":"circle"},"mode":"markers","name":"Argentina","orientation":"v","showlegend":true,"x":[69.06041666666667],"xaxis":"x","y":[28602239.916666668],"yaxis":"y","type":"scatter"},{"hovertemplate":"country=Bolivia<br>lifeExp=%{x}<
# ...

# %% [markdown]
# # Piecharts

# %%
px.data.gapminder().query("year==2007").\
    query("continent= ='Americas' and (country in ('Colombia','Uruguay','Argentina','Peru','Chile','Brazil','Ecuador','Venezuela','Paraguay','Bolivia'))")
# Out:
#         country continent  year  lifeExp        pop     gdpPercap iso_alpha  \
# 59    Argentina  Americas  2007   75.320   40301927  12779.379640       ARG
# 143     Bolivia  Americas  2007   65.554    9119152   3822.137084       BOL
# 179      Brazil  Americas  2007   72.390  190010647   9065.800825       BRA
# 287       Chile  Americas  2007   78.553   16284741  13171.638850       CHL
# 311    Colombia  Americas  2007   72.889   44227550   7006.580419       COL
# 455     Ecuador  Americas  2007   74.994   13755680   6873.262326       ECU
# 1199   Paraguay  Americas  2007   71.752    6667147   4172.838464       PRY
# 1211       Peru  Americas  2007   71.421   28674757   7408.905561       PER
# 1631    Uruguay  Americas  2007   76.384    3447496  10611.462990       URY
# 1643  Venezuela  Americas  2007   73.747   26084662  11415.805690       VEN
#
#       iso_num
# 59         32
# 143        68
# 179        76
# 287       152
# 311       170
# 455       218
# 1199      600
# ...

# %%
df_america= px.data.gapminder().query("year==2007").query("continent= ='Americas' and (country in ('Colombia','Uruguay','Argentina','Peru','Chile','Brazil','Ecuador','Venezuela','Paraguay','Bolivia'))")
px.pie(df_america, values='gdpPercap', names='country', title='Poblacion America',
       color_discrete_sequence= px.colors.sequential.RdBu)
# Out:
# <div>                            <div id="15aa146a-be2d-4def-a478-70653711ef86" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("15aa146a-be2d-4def-a478-70653711ef86")) {                    Plotly.newPlot(                        "15aa146a-be2d-4def-a478-70653711ef86",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"country=%{label}<br>gdpPercap=%{value}<extra></extra>","labels":["Argentina","Bolivia","Brazil","Chile","Colombia","Ecuador","Paraguay","Peru","Uruguay","Venezuela"],"legendgroup":"","name":"","showlegend":true,"values":[12779.37964,3822.137084,9065.800825,13171.63885,7006.580419,6873.262326000001,4172.838464,7408.905561,10611.46299,11415.80569],"type":"pie"}],                        {"template":{"data":{"h
# ...

# %%
df_america
# Out:
#         country continent  year  lifeExp        pop     gdpPercap iso_alpha  \
# 59    Argentina  Americas  2007   75.320   40301927  12779.379640       ARG
# 143     Bolivia  Americas  2007   65.554    9119152   3822.137084       BOL
# 179      Brazil  Americas  2007   72.390  190010647   9065.800825       BRA
# 287       Chile  Americas  2007   78.553   16284741  13171.638850       CHL
# 311    Colombia  Americas  2007   72.889   44227550   7006.580419       COL
# 455     Ecuador  Americas  2007   74.994   13755680   6873.262326       ECU
# 1199   Paraguay  Americas  2007   71.752    6667147   4172.838464       PRY
# 1211       Peru  Americas  2007   71.421   28674757   7408.905561       PER
# 1631    Uruguay  Americas  2007   76.384    3447496  10611.462990       URY
# 1643  Venezuela  Americas  2007   73.747   26084662  11415.805690       VEN
#
#       iso_num
# 59         32
# 143        68
# 179        76
# 287       152
# 311       170
# 455       218
# 1199      600
# ...

# %%
list(df_america.gdpPercap.values)
# Out:
# [12779.37964,
#  3822.137084,
#  9065.800825,
#  13171.63885,
#  7006.580419,
#  6873.262326000001,
#  4172.838464,
#  7408.905561,
#  10611.46299,
#  11415.80569]

# %%
len(list(df_america.country.values))
# Out:
# 10

# %%
fig= go.Figure(data=[go.Pie(labels=list(df_america.country.values),
                            values=list(df_america.gdpPercap.values))])
fig.update_traces(hoverinfo='label+percent', textfont_size=20,
                  textinfo= 'label+percent',pull=[0.2, 0,0, 0.2, 0, 0,0,0,0,0,0],
                  marker=dict(line=dict(color='#FFFFFF',width=2)))
fig
# Out:
# <div>                            <div id="e64c2c16-a4ad-49bc-82b4-a5bbaafe6b52" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e64c2c16-a4ad-49bc-82b4-a5bbaafe6b52")) {                    Plotly.newPlot(                        "e64c2c16-a4ad-49bc-82b4-a5bbaafe6b52",                        [{"labels":["Argentina","Bolivia","Brazil","Chile","Colombia","Ecuador","Paraguay","Peru","Uruguay","Venezuela"],"values":[12779.37964,3822.137084,9065.800825,13171.63885,7006.580419,6873.262326000001,4172.838464,7408.905561,10611.46299,11415.80569],"type":"pie","textfont":{"size":20},"marker":{"line":{"color":"#FFFFFF","width":2}},"hoverinfo":"label+percent","pull":[0.2,0,0,0.2,0,0,0,0,0,0,0],"textinfo":"label+percent"}],                        {"template":{"data
# ...

# %% [markdown]
# # Histogramas

# %%
df_ame
# Out:
#         country continent  year  lifeExp       pop     gdpPercap iso_alpha  \
# 48    Argentina  Americas  1952   62.485  17876956   5911.315053       ARG
# 49    Argentina  Americas  1957   64.399  19610538   6856.856212       ARG
# 50    Argentina  Americas  1962   65.142  21283783   7133.166023       ARG
# 51    Argentina  Americas  1967   65.634  22934225   8052.953021       ARG
# 52    Argentina  Americas  1972   67.065  24779799   9443.038526       ARG
# ...         ...       ...   ...      ...       ...           ...       ...
# 1639  Venezuela  Americas  1987   70.190  17910182   9883.584648       VEN
# 1640  Venezuela  Americas  1992   71.150  20265563  10733.926310       VEN
# 1641  Venezuela  Americas  1997   72.146  22374398  10165.495180       VEN
# 1642  Venezuela  Americas  2002   72.766  24287670   8605.047831       VEN
# 1643  Venezuela  Americas  2007   73.747  26084662  11415.805690       VEN
#
#       iso_num
# 48         32
# 49         32
# 50         32
# ...

# %%
df_ame=px.data.gapminder().query("continent= ='Americas' and (country in ('Colombia','Uruguay','Argentina','Peru','Chile','Brazil','Ecuador','Venezuela','Paraguay','Bolivia'))")
df_ame

fig=px.histogram(data_frame=df_ame,x='lifeExp',color='country',nbins=10)
fig.update_layout(
    title='Life Expectacy distirbution',
    xaxis_title='Edad',
    yaxis_title='Frecuencia',
    legend_title='Country',
    #barmode= 'overlay'
    plot_bgcolor='white',
    bargap=0.05
)
# Out:
# <div>                            <div id="641142fe-965f-4f02-abc1-5a81871d4e53" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("641142fe-965f-4f02-abc1-5a81871d4e53")) {                    Plotly.newPlot(                        "641142fe-965f-4f02-abc1-5a81871d4e53",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"country=Argentina<br>lifeExp=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Argentina","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Argentina","nbinsx":10,"offsetgroup":"Argentina","orientation":"v","showlegend":true,"x":[62.485,64.399,65.142,65.634,67.065,68.48100000000001,69.942,70.774,71.868,73.275,74.34,75.32],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingro
# ...

# %% [markdown]
# # Boxplots

# %%
fig=px.box(data_frame=df_ame,y='lifeExp', x='country',points='all')
fig
# Out:
# <div>                            <div id="9a7e1da2-4acb-40b7-891e-a7f0c9bcb9e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a7e1da2-4acb-40b7-891e-a7f0c9bcb9e6")) {                    Plotly.newPlot(                        "9a7e1da2-4acb-40b7-891e-a7f0c9bcb9e6",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"country=%{x}<br>lifeExp=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Bolivia","Bolivia","Bolivia","Bolivia","Bolivia","Bolivia","Bolivia","Bolivia","Bolivi
# ...

# %%
fig.write_html('Boxplot_prueba.html')

# %%
fig.write_image(file='Boxplot.jpeg', format='jpeg',width=800, height=400, scale=2.0)

# %%
df_stocks= px.data.stocks()
fig= go.Figure()
fig.add_trace(go.Box(y=df_stocks.GOOG, boxpoints='all',
                     fillcolor='blue',jitter=0.5,
                     whiskerwidth=0.2))
fig.add_trace(go.Box(y=df_stocks.AAPL, boxpoints='all',
                     fillcolor='red',jitter=0.5,
                     whiskerwidth=0.2))
fig.update_layout(title='Google vs Apple',yaxis=dict(gridcolor='rgb(255,255,255)',
                                                     gridwidth= 3),
                  paper_bgcolor='rgb(243, 243, 243)',
                  plot_bgcolor='rgb(243, 243, 210)')
# Out:
# <div>                            <div id="e2ed472d-d970-40c6-9565-d2016c7585c6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e2ed472d-d970-40c6-9565-d2016c7585c6")) {                    Plotly.newPlot(                        "e2ed472d-d970-40c6-9565-d2016c7585c6",                        [{"boxpoints":"all","fillcolor":"blue","jitter":0.5,"whiskerwidth":0.2,"y":[1.0,1.018172278347936,1.032007866452698,1.066782783389724,1.0087731636550117,0.9415276737437316,0.99325918262539,1.0222821547641083,0.9788520214265992,1.0524482730908842,1.0303929312465263,0.926821104067592,0.9360932452590338,0.913638710861412,0.93380695379017,0.9734447261178653,0.9345146364100892,0.9509902470625956,0.9963982380519172,0.9674568868105002,0.9758943718805396,1.015668254641377
# ...

# %% [markdown]
# # Heatmap

# %%
f= sns.load_dataset('flights')
fig= px.density_heatmap(f, x='year', y='month',z= 'passengers',
                        marginal_x= 'histogram',
                        marginal_y='histogram')
fig
# Out:
# <div>                            <div id="e29ccc2c-1a76-44b8-b4f4-0d271a52ea72" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e29ccc2c-1a76-44b8-b4f4-0d271a52ea72")) {                    Plotly.newPlot(                        "e29ccc2c-1a76-44b8-b4f4-0d271a52ea72",                        [{"coloraxis":"coloraxis","histfunc":"sum","hovertemplate":"year=%{x}<br>month=%{y}<br>sum of passengers=%{z}<extra></extra>","name":"","x":[1949,1949,1949,1949,1949,1949,1949,1949,1949,1949,1949,1949,1950,1950,1950,1950,1950,1950,1950,1950,1950,1950,1950,1950,1951,1951,1951,1951,1951,1951,1951,1951,1951,1951,1951,1951,1952,1952,1952,1952,1952,1952,1952,1952,1952,1952,1952,1952,1953,1953,1953,1953,1953,1953,1953,1953,1953,1953,1953,1953,1954,1954,1954,1954,1954,19
# ...

# %% [markdown]
# # Actividad

# %%
# !pip install gapminder

# %%
from gapminder import gapminder
gapminder.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
gapminder.tail()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
gapminder.year.unique()
# Out:
# array([1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002,
#        2007], dtype=int64)

# %%
import plotly.express as px
df_x= px.data.gapminder().query("year == 2007")
fig=px.bar(df_x, y='pop', x='country', text='pop', color='country')
fig.update_traces(texttemplate= '%{text:.2s}', textposition='outside')
fig.update_layout(uniformtext_minsize=8)
fig.update_layout(xaxis_tickangle= -45)
fig
# Out:
# <div>                            <div id="a5fcd75a-9fb8-4615-97e3-b71614cd5b6f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a5fcd75a-9fb8-4615-97e3-b71614cd5b6f")) {                    Plotly.newPlot(                        "a5fcd75a-9fb8-4615-97e3-b71614cd5b6f",                        [{"alignmentgroup":"True","hovertemplate":"country=%{x}<br>pop=%{text}<extra></extra>","legendgroup":"Afghanistan","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Afghanistan","offsetgroup":"Afghanistan","orientation":"v","showlegend":true,"text":[31889923.0],"textposition":"outside","x":["Afghanistan"],"xaxis":"x","y":[31889923],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"country=%{x}<br>pop=%{text}
# ...
