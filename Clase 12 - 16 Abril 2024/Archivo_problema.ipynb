# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2

ruta="C:/Users/Windows/Downloads/"
with open(ruta+'password.txt','r') as f:
    pwd= f.read()

#pd.options.display.max_rows = 50
hostname= 'localhost'
database= 'Call_Center'
username= 'postgres'
pwd=pwd
port_id= '5432'

engine= create_engine(f"postgresql://{username}:{pwd}@localhost:{port_id}/{database}")

# %%
engine
# Out:
# Engine(postgresql://postgres:***@localhost:5432/Call_Center)

# %%
tabla = pd.read_csv('ObesityDataSet_raw_and_data_sinthetic.csv').to_sql("Prue", engine, if_exists='replace', index=False)

# %%
engine
# Out:
# Engine(postgresql://postgres:***@localhost:5432/Call_Center)

# %%
from sqlalchemy import create_engine, inspect,text

inspector = inspect(engine)
table_names = inspector.get_table_names()
table_names
# Out:
# ['customers',
#  'agents',
#  'calls',
#  'product',
#  'productreview',
#  'productmodelproductdescriptionculture',
#  'productdescription',
#  'salesorderdetail',
#  'productcategory',
#  'productsubcategory',
#  'countryregioncurrency',
#  'currencyrate',
#  'PT',
#  'Prueba_David',
#  'Prue']

# %%
table_name = "PT"
from sqlalchemy import select
with engine.connect() as connection:
    #query = select([text('*')]).select_from(text(table_name))
    query = select([text('*')]).select_from(text('public."PT"'))
    result = connection.execute(query)
    rows = result.fetchall()

df = pd.DataFrame(rows, columns=result.keys())
df
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...
