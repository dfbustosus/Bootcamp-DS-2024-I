# %% [markdown]
# # Ejemplo 1

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
#import seaborn as sns
import pandas as pd

# %%
mpl.style.use('ggplot')

# %%
fig, ax = plt.subplots()
ax.plot([1, 3], [2, 4])

# %%
plt.plot([1, 3], [2, 4])

# %%
# Interfaz orientada a objetos
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10,6),sharex=True,sharey=True)
ax[0,0].plot([1, 3], [2, 4])
ax[0,1].plot([1, 3], [2, 4])
ax[1,0].plot([1, 2], [2, 4])
ax[1,1].plot([1, 3], [2.5, 4])

# %%
plt.plot([1, 3], [2, 4])
plt.plot([1, 2], [2, 5])

# %%
plt.subplots?

# %%
ax.plot?

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)
ax.plot([1, 3], [2, 4], color='green',marker='o',linestyle='--')
ax.plot([2, 5], [1, 2], color='r',marker='*',linestyle='--')
#ax.set_ylim([2,4])
#ax.set_xlim([1,3])
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Grafico x vs y',fontsize=12,weight='bold')
ax.axhline(y=3, xmin=0, xmax=4, color='b')
ax.axvline(x=2.0, ymin=0, ymax=10, color='b')

# %%
fig.savefig('Ejemplo.png', dpi=130)

# %%
import numpy as np
x= np.arange(-1000,1000,0.1)
y= x**2

# %%
#plt.plot([1, 3], [2, 4],color='b')
plt.plot(x, y,color='b')
#plt.ylim([2,4])
#plt.xlim([1,3])
plt.xlabel('x')
plt.ylabel('y')
plt.title('Grafico x vs y',fontsize=12,weight='bold')
# Out:
# Text(0.5, 1.0, 'Grafico x vs y')

# %% [markdown]
#  # Ejemplo 2

# %%
df_lluvias = pd.read_csv('pune_1965_to_2002.csv')
df_lluvias.head()
# Out:
#    Year    Jan    Feb    Mar     Apr     May      Jun      Jul      Aug  \
# 0  1965  0.029  0.069  0.000  21.667  17.859  102.111  606.071  402.521
# 1  1966  0.905  0.000  0.000   2.981  63.008   94.088  481.942   59.386
# 2  1967  0.248  3.390  1.320  13.482  11.116  251.314  780.006  181.069
# 3  1968  0.318  3.035  1.704  23.307   7.441  179.872  379.354  171.979
# 4  1969  0.248  2.524  0.334   4.569   6.213  393.682  678.354  397.335
#
#        Sep     Oct     Nov     Dec
# 0   69.511   5.249  16.232  22.075
# 1  150.624   1.308  41.214   4.132
# 2  183.757  50.404   8.393  37.685
# 3  219.884  73.997  23.326   2.020
# 4  205.413  24.014  24.385   1.951

# %%
df_lluvias.index = df_lluvias['Year']
df_lluvias = df_lluvias.drop('Year', axis='columns')
df_lluvias.head()
# Out:
#         Jan    Feb    Mar     Apr     May      Jun      Jul      Aug      Sep  \
# Year
# 1965  0.029  0.069  0.000  21.667  17.859  102.111  606.071  402.521   69.511
# 1966  0.905  0.000  0.000   2.981  63.008   94.088  481.942   59.386  150.624
# 1967  0.248  3.390  1.320  13.482  11.116  251.314  780.006  181.069  183.757
# 1968  0.318  3.035  1.704  23.307   7.441  179.872  379.354  171.979  219.884
# 1969  0.248  2.524  0.334   4.569   6.213  393.682  678.354  397.335  205.413
#
#          Oct     Nov     Dec
# Year
# 1965   5.249  16.232  22.075
# 1966   1.308  41.214   4.132
# 1967  50.404   8.393  37.685
# 1968  73.997  23.326   2.020
# 1969  24.014  24.385   1.951

# %%
david=df_lluvias.rolling(window=2).mean()
x_new= david.index
y_new= david.sum(axis='columns')

fig, ax = plt.subplots(nrows=1, ncols=1,figsize=(16, 8))
ax.plot(x_new, y_new, label='Precipitaciones acumuladas',color='r',marker='*')
ax.plot(x_new, y_new-300, label='Pr',color='b',marker='s')
ax.set_xlabel('Año')                  
ax.set_ylabel('Precipitación acumulada (mm.)')
ax.set_title('Precipitaciones acumuladas según el año')
ax.legend(loc='upper left')

# %%
x = df_lluvias.index
y = df_lluvias.sum(axis='columns')

# %%
fig, ax = plt.subplots(nrows=1, ncols=1,figsize=(16, 8))
ax.plot(x, y, label='Precipitaciones acumuladas',color='r',marker='o')
ax.plot(x, y-300, label='Pr',color='b',marker='s')
ax.set_xlabel('Año')                  
ax.set_ylabel('Precipitación acumulada (mm.)')
ax.set_title('Precipitaciones acumuladas según el año')
ax.legend(loc='upper left')

# %%
fig.savefig("precipitaciones_año.pdf")

# %%
fig.savefig("precipitaciones_año.jpeg",dpi=130)

# %%
fig.savefig("precipitaciones_año.tiff",dpi=130)

# %%
fig,ax= plt.subplots(nrows=2, ncols=1, figsize=(12,4),sharey=True,sharex=True)
ax[0].plot(x, y, label='Precipitaciones acumuladas',color='r')
ax[1].plot(x, y-600, label='Precipitaciones',color='b')

# %%
fig,ax= plt.subplots(nrows=1, ncols=2, figsize=(12,4),sharey=True)
ax[0].plot(x, y, label='Precipitaciones acumuladas',color='r')
ax[1].plot(x, y-600, label='Precipitaciones',color='b')

# %%
fig,ax= plt.subplots(nrows=2, ncols=2, figsize=(12,4),sharey=True,sharex=True)
ax[0,0].plot(x, y, label='Precipitaciones acumuladas',color='r')
ax[0,1].plot(x, y-600, label='Precipitaciones',color='b')
ax[1,0].plot(x, y, label='Precipitaciones acumuladas',color='r')
ax[1,1].plot(x, y-600, label='Precipitaciones',color='b')

# %%
f, (at,at1) = plt.subplots(nrows=1, ncols=2,figsize=(12, 4),sharex=True, sharey=True)
at.plot(x, y, label='Precipitaciones acumuladas',color='r')
at.set_xlabel('year')
at.set_ylabel('Precp')

at1.plot(x, y-800, label='Precipitaciones acumuladas',color='b')
at1.set_xlabel('year')
#at1.set_ylabel('Precp')
# Out:
# Text(0.5, 0, 'year')

# %%
ax.set_ylabel?

# %%
fig.savefig("precipitaciones_año.pdf")

# %%
fig.savefig("precipitaciones_año.tiff")

# %% [markdown]
# # Lineplot

# %%
fig, ax = plt.subplots()
ax.plot([0, 1, 2, 3, 4, 5, 6], [1, 5, 2, 4, 8, 9, 2],color='green',linewidth=1,marker='s',\
        linestyle='--',markersize=5)

# %%
fig, ax = plt.subplots()
ax.plot([1, 5, 2, 4, 8, 9, 2])
ax.set_xticks([0,1,2,3,4,5,6])
ax.set_xticklabels(['ene','feb','mar','abr','may','jun','jul'])
# Out:
# [Text(0, 0, 'ene'),
#  Text(1, 0, 'feb'),
#  Text(2, 0, 'mar'),
#  Text(3, 0, 'abr'),
#  Text(4, 0, 'may'),
#  Text(5, 0, 'jun'),
#  Text(6, 0, 'jul')]

# %% [markdown]
# # Scatterplot

# %%
pesos = [42.8, 43.3, 42. , 44. , 44.1, 43.5, 48.1, 48.9, 47.7,46.9,50.4,
       52.7, 51.8, 54.5, 54.2, 56.9, 55.4, 55.5, 57.1, 58.3, 63.7, 58.8,
       64.6, 60.2, 64. , 63.8, 61.4, 66.3, 64.7, 63.9, 69.3, 67.9, 65.2,
       70.8, 70.5, 69.3, 75.3, 75.5, 78.2, 78. , 73.2, 78. , 80.1, 78.2,
       76. , 81.5, 79.4, 81.8, 81.8, 84.1]
alturas = [149. , 149. , 149.9, 156.8, 150.6, 155.4, 151. , 162. , 165.,
       157.8, 164.4, 160.1, 160.8, 163.8, 175.2, 162. , 159.5, 159.2,
       169.8, 166.7, 179.4, 180.6, 163.3, 178.8, 176.3, 184.8, 181. ,
       170.5, 184.1, 187.1, 187.1, 177.7, 184.5, 190.3, 196. , 192.1,
       200.4, 201.8, 187.5, 202.1, 200.3, 208.8, 204.6, 193.5, 200.9,
       196.8, 213.1, 204.8, 215.5, 210.2] 
sizes=[42.8, 43.3, 42. , 44. , 44.1, 43.5, 48.1, 48.9, 47.7,46.9,50.4,
       52.7, 51.8, 54.5, 54.2, 56.9, 55.4, 55.5, 57.1, 58.3, 63.7, 58.8,
       64.6, 60.2, 64. , 63.8, 61.4, 66.3, 64.7, 63.9, 69.3, 67.9, 65.2,
       70.8, 70.5, 69.3, 75.3, 75.5, 78.2, 78. , 73.2, 78. , 80.1, 78.2,
       76. , 81.5, 79.4, 81.8, 81.8, 84.1]

# %%
ax.scatter?

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12,6))
ax.scatter(x=alturas, y=pesos,s=sizes, alpha=0.6,color='b',marker='o')
ax.set_title('Altura vs. Peso de 50 alumnos')
ax.set_xlabel('Altura (cm.)')
ax.set_ylabel('Peso (kg.)')
# Out:
# Text(0, 0.5, 'Peso (kg.)')

# %% [markdown]
# # Barplot

# %%
df_lluvias.columns
# Out:
# Index(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct',
#        'Nov', 'Dec'],
#       dtype='object')

# %%
df_lluvias.sum(axis='rows')
# Out:
# Jan       11.186
# Feb       41.843
# Mar       63.733
# Apr      470.487
# May      952.272
# Jun    12809.663
# Jul    16340.395
# Aug    10529.357
# Sep     7642.245
# Oct     2783.320
# Nov      958.492
# Dec      230.646
# dtype: float64

# %%
precipitaciones_acumuladas = df_lluvias.sum()
precipitaciones_acumuladas
# Out:
# Jan       11.186
# Feb       41.843
# Mar       63.733
# Apr      470.487
# May      952.272
# Jun    12809.663
# Jul    16340.395
# Aug    10529.357
# Sep     7642.245
# Oct     2783.320
# Nov      958.492
# Dec      230.646
# dtype: float64

# %%
ax.bar?

# %%
df_lluvias.columns
# Out:
# Index(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct',
#        'Nov', 'Dec'],
#       dtype='object')

# %%
df_lluvias.sum(axis='rows')
# Out:
# Jan       11.186
# Feb       41.843
# Mar       63.733
# Apr      470.487
# May      952.272
# Jun    12809.663
# Jul    16340.395
# Aug    10529.357
# Sep     7642.245
# Oct     2783.320
# Nov      958.492
# Dec      230.646
# dtype: float64

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax.bar(df_lluvias.columns, df_lluvias.sum(axis='rows'),color='g')
ax.set_title('Precipitaciones acumuladas desde 1965 a 2002, según el mes')
ax.set_ylabel('Precipitación total (mm.)')
ax.set_xlabel('Mes')
ax.text(6-0.3,16500,'Hola',fontsize=8,color='red',fontweight='bold')
ax.text(2,1500,'Hola',fontsize=8,color='red',fontweight='bold')
# Out:
# Text(2, 1500, 'Hola')

# %% [markdown]
# # Histograma

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.hist(df_lluvias.values.flatten())
ax.set_title('Histograma de precipitaciones')
ax.set_xlabel('Intervalos de precipitaciones (mm.)')
ax.set_ylabel('Frecuencia absoluta')
# Out:
# Text(0, 0.5, 'Frecuencia absoluta')

# %% [markdown]
# # Boxplot

# %%
df_lluvias

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.boxplot(df_lluvias,showfliers=True)
ax.set_title('Boxplot de precipitaciones')
ax.set_xlabel('Meses')
ax.set_ylabel('Precipitacion (mm)')
# Out:
# Text(0, 0.5, 'Precipitacion (mm)')

# %% [markdown]
# $$\color{blue}{\textbf{Voy por el aqui}}$$

# %% [markdown]
# # Piechart

# %%
cars = ['AUDI', 'BMW', 'FORD',
        'TESLA', 'JAGUAR', 'MERCEDES']
 
data = [23, 17, 35, 29, 12, 41]

fig,ax = plt.subplots(figsize =(10, 7))
ax.pie(data, labels = cars,)
# Out:
# ([<matplotlib.patches.Wedge at 0x149df40d720>,
# ...
#  [Text(0.9855437775757192, 0.4885728834900496, 'AUDI'),
#   Text(0.33572919201948, 1.0475141572436848, 'BMW'),
#   Text(-0.7338600808214595, 0.8194201497258419, 'FORD'),
#   Text(-0.9951222150817397, -0.4687555621545326, 'TESLA'),
#   Text(-0.3357291429818033, -1.0475141729603012, 'JAGUAR'),
#   Text(0.7501087862487479, -0.8045724384991263, 'MERCEDES')])

# %% [markdown]
# # Modificación de hiperparametros graficos

# %%
fig, ax = plt.subplots(figsize=(12, 3))  
ax.plot(df_lluvias.index, df_lluvias['Jan'], label='Precipitaciones de enero')
ax.plot(df_lluvias.index, df_lluvias['Feb'], label='Precipitaciones de febrero', color='C1')
maximo_enero = df_lluvias['Jan'].max()
maximo_febrero =  df_lluvias['Feb'].max()
ax.axhline(maximo_enero, color='red', linestyle='--', alpha=0.5,    linewidth=3, label='Máxima de enero')
ax.axhline(maximo_febrero, color='red', linestyle=':', alpha=0.5, linewidth=3, label='Máxima de febrero')
ax.set_xlabel('Año')  
ax.set_ylabel('Precipitación (mm.)') 
ax.set_title('Precipitaciones de enero y febrero')     
ax.set_xlim(df_lluvias.index[0], df_lluvias.index[-1])
ax.legend()

# %%
mpl.rcParams.keys()
# Out:
# KeysView(RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': ['-layers', 'OptimizePlus'],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': 'line',
#           'axes.edgecolor': 'black',
#           'axes.facecolor': 'white',
#           'axes.formatter.limits': [-5, 6],
#           'axes.formatter.min_exponent': 0,
#           'axes.formatter.offset_threshold': 4,
#           'axes.formatter.use_locale': False,
#           'axes.formatter.use_mathtext': False,
#           'axes.formatter.useoffset': True,
# ...

# %%
mpl.rcParams['axes.titleweight'] = 'bold' 
mpl.rcParams['axes.titlelocation'] = 'left' 
mpl.rcParams['axes.titlecolor'] = 'firebrick' 
mpl.rcParams['axes.labelcolor'] = 'blue' 
mpl.rcParams['axes.labelsize'] = '10' 
mpl.rcParams['axes.labelweight'] = 'light' 
mpl.rcParams['axes.linewidth'] = '1' 
mpl.rcParams['grid.color'] = 'black' 
mpl.rcParams['grid.linestyle'] = '-.' 
mpl.rcParams['grid.linewidth'] = '2'

# %%
fig, ax = plt.subplots(figsize=(7, 4))  
ax.scatter(df_lluvias['Aug'], df_lluvias['Sep'], c=df_lluvias.index)
ax.set_title('(Título rojo en negrita)')
ax.set_xlabel('(Etiqueta eje horiz.)')
ax.set_ylabel('(Etiqueta eje vert.)')
plt.show()

# %%
# Resetear parametros por defecto
mpl.rcParams.update(mpl.rcParamsDefault)

# %%
fig, ax = plt.subplots(figsize=(7, 4))  
ax.scatter(df_lluvias['Aug'], df_lluvias['Sep'], c=df_lluvias.index)
ax.set_title('(Título rojo en negrita)')
ax.set_xlabel('(Etiqueta eje horiz.)')
ax.set_ylabel('(Etiqueta eje vert.)')
plt.show()

# %% [markdown]
# # Desafio generico

# %%
data=pd.read_csv('HRDataset_v14.csv',sep=',')
data.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
data.shape
# Out:
# (311, 36)

# %%
data.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %%
# Verificamos si hay nulos primero
data.isnull().sum()
# Out:
# Employee_Name                   0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             207
# TermReason                      0
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ...

# %% [markdown]
# # Grafico 1: histograma para ver distribucion del salario

# %%
#from IPython.display import display

# %%
# Orientado a objetos
mpl.style.use('classic')
fig, ax = plt.subplots(figsize=(10,6))
ax.hist(x= data.Salary, bins=None, density=False, orientation='vertical')
ax.set_xlabel('Salario')
ax.set_ylabel('Frecuencia')
ax.set_title('Histograma de Salario')
#fig.show()
display(fig)

# %%
# Orientado a estados
mpl.style.use('classic')
plt.figure(figsize=(10,6))
plt.hist(x= data.Salary, bins=None, density=False, orientation='vertical')
plt.xlabel('Salario')
plt.ylabel('Frecuencia')
plt.title('Histograma de Salario')
display(fig)

# %% [markdown]
# Se logra ver que la distribucion de los datos es asimetrica a derecha con la mayoria de valores en la parte inferior de la distribucion (valores tipicos entre 50000-100000). Se logra ver tambien que hay presencia de valores por encima de 2000000

# %% [markdown]
# # Grafico 2: Piechart para ver distribucion de empleados por departamento

# %%
data_2=data[['EmpID','Department']].groupby(by='Department').count()
data_2
# Out:
#                       EmpID
# Department
# Admin Offices             9
# Executive Office          1
# IT/IS                    50
# Production              209
# Sales                    31
# Software Engineering     11

# %%
data_2.index
# Out:
# Index(['Admin Offices', 'Executive Office', 'IT/IS', 'Production       ',
#        'Sales', 'Software Engineering'],
#       dtype='object', name='Department')

# %%
fig,ax = plt.subplots(figsize =(10, 6))
ax.pie(data_2.EmpID, labels = data_2.index,autopct='%1.1f%%')
ax.set_title('Piechart de distribucion de departamento')
display(fig)

# %%
plt.figure(figsize=(10,6))
plt.pie(data_2.EmpID, labels = data_2.index,autopct='%1.1f%%')
plt.title('Piechart de distribucion de departamento')
plt.show()

# %% [markdown]
# # Grafico 3:

# %%
serie_estatus=data.MaritalDesc.value_counts()
serie_estatus
# Out:
# MaritalDesc
# Single       137
# Married      124
# Divorced      30
# Separated     12
# Widowed        8
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.bar(serie_estatus.index, serie_estatus)
ax.set_title('Frecuencia de estado civil')
ax.set_ylabel('Frecuencia')
ax.set_xlabel('Estado civil')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.bar(serie_estatus.index, serie_estatus)
plt.title('Frecuencia de estado civil')
plt.ylabel('Frecuencia')
plt.xlabel('Estado civil')
plt.show()
