# %% [markdown]
# # 1. Libraries

# %%
import seaborn as sns 
import pandas as pd 
import os
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # 2. Load data

# %%
df = pd.read_csv('./HRDataset_v14.csv',sep=',')
df
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...

# %%
df.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Employee_Name                   0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             207
# TermReason                      0
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
# ...

# %% [markdown]
# - Data Extraction (Pandas,.. SQL, NoSQL, Conectores)
# - EDA: Exploratory Data Analysis (Paradoja de Simpson!)
# - Data Cleaning/ Data Munging/ Data Wrangling: Duplicados, Atipicos, Nulos
# - Data Modeling : Saber elegir el mejor modelo (saber cuando no usar un modelo)
# - Model Validation: Probar que el modelo funciona
# - Deploy , CI & CD: Deployment

# %% [markdown]
# # 3. EDA = Exploratory Data Analysis

# %%
df.Absences
# Out:
# 0       1
# 1      17
# 2       3
# 3      15
# 4       2
#        ..
# 306    13
# 307     4
# 308    16
# 309    11
# 310     2
# Name: Absences, Length: 311, dtype: int64

# %% [markdown]
# # 3.1 Relplot

# %%
sns.relplot(data=df, x='Absences',y='Salary',kind='scatter')

# %%
sns.scatterplot(data=df, x='Absences',y='Salary')
# Out:
# <Axes: xlabel='Absences', ylabel='Salary'>

# %%
df['DateofHire']=pd.to_datetime(df['DateofHire'])
df['FechaSimple']=df['DateofHire'].dt.strftime('%Y-%m')
tabla_serie= df[['FechaSimple','Salary']].groupby(by=['FechaSimple']).count().reset_index()
tabla_serie
# Out:
#    FechaSimple  Salary
# 0      2006-01       1
# 1      2007-06       1
# 2      2007-11       1
# 3      2008-01       1
# 4      2008-09       1
# ..         ...     ...
# 65     2016-10       2
# 66     2017-01       1
# 67     2017-02       3
# 68     2017-04       2
# 69     2018-07       1
#
# [70 rows x 2 columns]

# %%
df['DateofHire']=pd.to_datetime(df['DateofHire'])
df['FechaSimple']=df['DateofHire'].dt.strftime('%Y-%m')
tabla_serie= df[['FechaSimple','Salary']].groupby(by=['FechaSimple']).count().reset_index()
plt.figure(figsize=(24,12))
#fig, ax= plt.subplots(figsize=(18,6))
sns.relplot(data=tabla_serie, x='FechaSimple',y='Salary',kind='line', )
plt.xticks(rotation=45)
plt.title('Serie de tiempo')
# Out:
# Text(0.5, 1.0, 'Serie de tiempo')

# %%
plt.figure(figsize=(18,6))
sns.lineplot(data=tabla_serie, x='FechaSimple',y='Salary')
plt.xticks(rotation=90)
plt.title('Serie de tiempo')
# Out:
# Text(0.5, 1.0, 'Serie de tiempo')

# %% [markdown]
# # 3.2 Distplot

# %%
sns.histplot(data=df, x='Salary')
# Out:
# <Axes: xlabel='Salary', ylabel='Count'>

# %%
sns.kdeplot(data=df, x='Salary')
# Out:
# <Axes: xlabel='Salary', ylabel='Density'>

# %%
sns.ecdfplot(data=df, x='Salary')
# Out:
# <Axes: xlabel='Salary', ylabel='Proportion'>

# %%
#sns.rugplot(x= np.array([1,2,3]), y=np.array([1,4,5]))

# %%
sns.displot(data=df, x='Salary',kind='hist')

# %%
sns.displot(data=df, x='Salary',kind='ecdf')

# %%
sns.displot(data=df, x='Salary',kind='kde')

# %% [markdown]
# # 3.3 Catplot

# %%
df.dtypes
# Out:
# Employee_Name                         object
# EmpID                                  int64
# MarriedID                              int64
# MaritalStatusID                        int64
# GenderID                               int64
# EmpStatusID                            int64
# DeptID                                 int64
# PerfScoreID                            int64
# FromDiversityJobFairID                 int64
# Salary                                 int64
# Termd                                  int64
# PositionID                             int64
# Position                              object
# State                                 object
# Zip                                    int64
# DOB                                   object
# Sex                                   object
# MaritalDesc                           object
# CitizenDesc                           object
# HispanicLatino                        object
# RaceDesc                              object
# ...

# %%
df['Mes']=df['DateofHire'].dt.month
df
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...

# %%
sns.catplot?

# %%
sns.catplot(data=df, x='Mes',y='Salary',kind='box')

# %%
sns.catplot(data=df, x='Mes',y='Salary',kind='violin')

# %%
sns.catplot(data=df, x='Mes',y='Salary',kind='strip')

# %%
sns.boxplot(data=df, x='Mes',y='Salary')
# Out:
# <Axes: xlabel='Mes', ylabel='Salary'>

# %%
sns.violinplot(data=df, x='Mes',y='Salary')
# Out:
# <Axes: xlabel='Mes', ylabel='Salary'>

# %%
sns.stripplot(data=df, x='Mes',y='Salary')
# Out:
# <Axes: xlabel='Mes', ylabel='Salary'>

# %%
df['MaritalDesc'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='MaritalDesc'>

# %%
t=pd.DataFrame(df['MaritalDesc'].value_counts()).reset_index()
sns.barplot(data=t, x='MaritalDesc',y='count')
# Out:
# <Axes: xlabel='MaritalDesc', ylabel='count'>

# %% [markdown]
# # 4. FacetGrid

# %%
df.Sex.unique()
# Out:
# array(['M ', 'F'], dtype=object)

# %%
df.RaceDesc.unique()
# Out:
# array(['White', 'Black or African American', 'Two or more races', 'Asian',
#        'American Indian or Alaska Native', 'Hispanic'], dtype=object)

# %%
df.PerformanceScore.unique()
# Out:
# array(['Exceeds', 'Fully Meets', 'Needs Improvement', 'PIP'], dtype=object)

# %%
# g= sns.FacetGrid(data=df, col='PerformanceScore', row='Sex')
# g.map(sns.histplot, 'Salary')
